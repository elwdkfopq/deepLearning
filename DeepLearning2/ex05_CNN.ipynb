# %% [markdown]
# # CNN을 이용한 이미지 분류
# - 학습 내용
#   - 손글씨 숫자 이미지 데이터 전처리
#     - 색상 차원 추가
#     - 정규화 (0-255 -> 0.0-1.0
#   - Conv2D(), MaxPooling2D(), Flatten() 사용
#   - 손글씨 숫자 분류

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
# 훈련데이터 2000개, 테스트데이터 500개만 사용
X_train = X_train[:2000]
y_train = y_train[:2000]
X_test = X_test[:500]
y_test = y_test[:500]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2000, 28, 28), (2000,), (500, 28, 28), (500,))

# %% [markdown]
# - 데이터 전처리
#   - 색상 차원 추가 (CNN은 색상차원이 필요)
#   - 정규화 (0-255 -> 0.0-1.0) : 분산 감소 -> 성능 개선

# %%
# 색상차원 추가
# (2000, 28, 28), (500,28,28) -> (2000, 28, 28,1), (500,28,28,1)
# 1을 하나 더 추가하는정도는 할 수 있음. 단순 차원하나 늘리는거라서
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1,28,28,1)

X_train.shape, X_test.shape
# Out:
# ((2000, 28, 28, 1), (500, 28, 28, 1))

# %%
# 정규화. 최댓값으로 나눔
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# - y를 원핫인코딩. 왜하는지  5-1일 영상을 다시 봐바.. 마지막에서2번째 교시임

# %%
# to_categorical() : 원핫인코딩하는 함수. 숫자로된 값만 가능
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

y_train.shape, y_test.shape
# Out:
# ((2000, 10), (500, 10))

# %% [markdown]
# # CNN을 이용한 신경망 설계
# - Conv2D(): 데이터로부터 특성을 추출하는 기능
#   - 데이터에 필터를 이용하여 컨볼루션 수행
#   - filters: 필터의 수
#   - kernel_size: 필터의 크기
#   - input_shape: 입력 데이터의 크기(입력층만 설정하면 됨)
#   - padding: same으로 하면 크기가 고정
# - MaxPooling2D(): 추출된 특성의 크기를 줄이는 기능
#   - pool_size: 표본 대사의 크기 (2,2)이면 4배로 크기가 감소
# - Flatten(): 특성 데이터를 1차원으로 만드는 기능

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D,Flatten, Dense

model = Sequential()

# 특성추출기
# C (Conv2D), M(Maxpooling) 층을 쌓는 방법: C-M, C-C-M, C-C-C-M
# 신경망층을 몇 층을 쌓을까: 최종크기?가 4~20 범위가 되기까지 쌓음?
model.add(Conv2D(filters=32, kernel_size=(3,3),
                 input_shape=(28,28,1),
                 padding='valid')) # 제로패딩 안함. 크기 줄어듦. 디폴트값
model.add(Conv2D(filters=64, kernel_size=(3,3),
                 padding='same')) # 크기 줄어듦, 대부분 이거씀
model.add(MaxPooling2D(pool_size=(2,2)))

# 1차원으로 변환
model.add(Flatten())

# 분류기
model.add(Dense(128, activation="relu"))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 10816)             0
#
#  dense_2 (Dense)             (None, 128)               1384576
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1404682 (5.36 MB)
# Trainable params: 1404682 (5.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

# %% [markdown]
# - 베스트모델 저장, 학습중단 기능

# %% [markdown]
# - 학습

# %%
h1 = model.fit(X_train, y_train, batch_size=100,
               epochs=30, validation_data=[X_test, y_test])
# Out:
# Epoch 1/30
# 20/20 [==============================] - 7s 283ms/step - loss: 0.8944 - accuracy: 0.7325 - val_loss: 0.4752 - val_accuracy: 0.8480
# Epoch 2/30
# 20/20 [==============================] - 5s 237ms/step - loss: 0.3014 - accuracy: 0.9060 - val_loss: 0.3448 - val_accuracy: 0.8860
# Epoch 3/30
# 20/20 [==============================] - 6s 306ms/step - loss: 0.1676 - accuracy: 0.9505 - val_loss: 0.2871 - val_accuracy: 0.9060
# Epoch 4/30
# 20/20 [==============================] - 5s 253ms/step - loss: 0.1029 - accuracy: 0.9705 - val_loss: 0.2568 - val_accuracy: 0.9180
# Epoch 5/30
# 20/20 [==============================] - 6s 327ms/step - loss: 0.0580 - accuracy: 0.9850 - val_loss: 0.2842 - val_accuracy: 0.9240
# Epoch 6/30
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0256 - accuracy: 0.9960 - val_loss: 0.2811 - val_accuracy: 0.9240
# Epoch 7/30
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0135 - accuracy: 0.9980 - val_loss: 0.2932 - val_accuracy: 0.9180
# Epoch 8/30
# 20/20 [==============================] - 6s 301ms/step - loss: 0.0075 - accuracy: 0.9995 - val_loss: 0.3053 - val_accuracy: 0.9120
# Epoch 9/30
# 20/20 [==============================] - 5s 231ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.3000 - val_accuracy: 0.9260
# Epoch 10/30
# 20/20 [==============================] - 6s 293ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9300
# Epoch 11/30
# 20/20 [==============================] - 5s 234ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3180 - val_accuracy: 0.9280
# Epoch 12/30
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3141 - val_accuracy: 0.9280
# Epoch 13/30
# 20/20 [==============================] - 5s 270ms/step - loss: 8.3442e-04 - accuracy: 1.0000 - val_loss: 0.3187 - val_accuracy: 0.9260
# Epoch 14/30
# 20/20 [==============================] - 5s 226ms/step - loss: 7.1352e-04 - accuracy: 1.0000 - val_loss: 0.3236 - val_accuracy: 0.9280
# Epoch 15/30
# 20/20 [==============================] - 6s 287ms/step - loss: 6.1699e-04 - accuracy: 1.0000 - val_loss: 0.3263 - val_accuracy: 0.9280
# Epoch 16/30
# 20/20 [==============================] - 5s 226ms/step - loss: 5.4277e-04 - accuracy: 1.0000 - val_loss: 0.3295 - val_accuracy: 0.9220
# Epoch 17/30
# 20/20 [==============================] - 5s 232ms/step - loss: 4.8099e-04 - accuracy: 1.0000 - val_loss: 0.3314 - val_accuracy: 0.9260
# Epoch 18/30
# 20/20 [==============================] - 6s 293ms/step - loss: 4.3775e-04 - accuracy: 1.0000 - val_loss: 0.3346 - val_accuracy: 0.9240
# Epoch 19/30
# 20/20 [==============================] - 5s 241ms/step - loss: 3.9185e-04 - accuracy: 1.0000 - val_loss: 0.3380 - val_accuracy: 0.9240
# Epoch 20/30
# 20/20 [==============================] - 6s 295ms/step - loss: 3.5188e-04 - accuracy: 1.0000 - val_loss: 0.3405 - val_accuracy: 0.9240
# Epoch 21/30
# 20/20 [==============================] - 5s 255ms/step - loss: 3.2127e-04 - accuracy: 1.0000 - val_loss: 0.3428 - val_accuracy: 0.9240
# Epoch 22/30
# 20/20 [==============================] - 6s 293ms/step - loss: 2.9357e-04 - accuracy: 1.0000 - val_loss: 0.3444 - val_accuracy: 0.9240
# Epoch 23/30
# 20/20 [==============================] - 5s 245ms/step - loss: 2.7068e-04 - accuracy: 1.0000 - val_loss: 0.3470 - val_accuracy: 0.9240
# Epoch 24/30
# 20/20 [==============================] - 5s 244ms/step - loss: 2.5078e-04 - accuracy: 1.0000 - val_loss: 0.3490 - val_accuracy: 0.9240
# Epoch 25/30
# 20/20 [==============================] - 6s 305ms/step - loss: 2.2969e-04 - accuracy: 1.0000 - val_loss: 0.3505 - val_accuracy: 0.9240
# Epoch 26/30
# 20/20 [==============================] - 5s 232ms/step - loss: 2.1409e-04 - accuracy: 1.0000 - val_loss: 0.3527 - val_accuracy: 0.9240
# Epoch 27/30
# 20/20 [==============================] - 5s 275ms/step - loss: 1.9845e-04 - accuracy: 1.0000 - val_loss: 0.3548 - val_accuracy: 0.9240
# Epoch 28/30
# 20/20 [==============================] - 6s 302ms/step - loss: 1.8736e-04 - accuracy: 1.0000 - val_loss: 0.3562 - val_accuracy: 0.9240
# Epoch 29/30
# 20/20 [==============================] - 5s 227ms/step - loss: 1.7377e-04 - accuracy: 1.0000 - val_loss: 0.3586 - val_accuracy: 0.9240
# Epoch 30/30
# 20/20 [==============================] - 6s 288ms/step - loss: 1.6291e-04 - accuracy: 1.0000 - val_loss: 0.3594 - val_accuracy: 0.9220
